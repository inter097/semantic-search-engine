# %%
import csv

# Listas de títulos y resúmenes sobre Epilepsia (20 items)
epilepsy_titles = [
    "Introduction to Epilepsy",
    "Current Treatments for Epilepsy",
    "Causes of Epilepsy",
    "Diagnosis of Epilepsy",
    "Living with Epilepsy",
    "Types of Epilepsy",
    "Seizure Triggers",
    "Stigma and Epilepsy",
    "Recent Research in Epilepsy",
    "Childhood Epilepsy",
    "Psychological Support",
    "Treatment Adherence",
    "Refractory Epilepsy",
    "Seizure Classification",
    "Socioeconomic Impact",
    "Epilepsy and Depression",
    "Genetics of Epilepsy",
    "Nocturnal Seizures",
    "Safety and Epilepsy",
    "Effects of Stigma"
]

epilepsy_summaries = [
    "Epilepsy is a neurological disorder characterized by recurrent seizures. These seizures are temporary episodes of abnormal electrical activity in the brain that can affect behavior, movements, sensations, and consciousness.",
    "The treatment of epilepsy typically includes anticonvulsant medications, but in resistant cases, options such as surgery, vagus nerve stimulation, or special diets like the ketogenic diet may be considered.",
    "The causes of epilepsy are varied and include genetic factors, brain injuries, infections, and conditions such as stroke. However, in many cases, the exact cause cannot be determined.",
    "Diagnosis of epilepsy is performed through the patient's medical history, a neurological exam, and complementary tests such as electroencephalogram (EEG) and magnetic resonance imaging (MRI).",
    "Living with epilepsy can be challenging, but with proper treatment and social support, many individuals with epilepsy lead full and active lives.",
    "There are different types of epilepsy, such as focal epilepsy and generalized epilepsy, each with distinct clinical features and prognoses.",
    "Seizure triggers can include lack of sleep, stress, flashing lights, and alcohol consumption. Identifying and avoiding these triggers is part of epilepsy management.",
    "Epilepsy is a stigmatized condition in many cultures, leading to discrimination and social isolation for those affected.",
    "Recent research is exploring new treatments for epilepsy, including gene therapies and new anticonvulsant drugs with fewer side effects.",
    "Childhood epilepsy addresses the diagnosis and treatment of epilepsy in children, considering the impact on cognitive and social development.",
    "Psychological support is crucial for epilepsy patients, helping them manage the stress and anxiety associated with the condition.",
    "Adherence to treatment is critical in epilepsy to prevent seizures, but many patients face challenges in maintaining their medication regimen.",
    "Refractory epilepsy is epilepsy that does not respond to conventional treatments, requiring alternative therapeutic approaches.",
    "Epileptic seizures can be classified into simple partial, complex partial, and generalized tonic-clonic seizures, each with specific symptoms.",
    "The socioeconomic impact of epilepsy is significant, affecting work productivity and generating healthcare costs.",
    "Epilepsy and depression often coexist, requiring an integrated approach to treatment to address both conditions.",
    "Genetics plays a role in some types of epilepsy, and specific genes increasing the risk of developing this disorder are being identified.",
    "Nocturnal seizures are common in epilepsy and can affect the quality of sleep for both the patient and their family members.",
    "Epilepsy can influence activities such as driving and other tasks requiring constant attention, so precautions must be taken to ensure patient safety.",
    "The stigma associated with epilepsy can affect the self-esteem and interpersonal relationships of affected individuals."
]

# Listas de títulos y resúmenes sobre Creación de Ontologías en Medicina (20 items)
ontology_titles = [
    "Fundamentals of Medical Ontologies",
    "Ontology Creation Process",
    "Interoperability in Health Systems",
    "Clinical Applications of Ontologies",
    "Tools for Ontology Development",
    "Standard Medical Ontologies",
    "Shared Semantics in Health",
    "Integration with EHR Systems",
    "Semantic Searching in Medicine",
    "Semantic Interoperability",
    "Collaboration in Ontology Development",
    "Ontologies in Clinical Research",
    "Support for Artificial Intelligence",
    "Ontology Maintenance and Updates",
    "Reusing Existing Ontologies",
    "Version Management in Ontologies",
    "Ontologies and the Semantic Web",
    "Impact of Medical Ontologies",
    "Evaluating Ontology Quality",
    "Healthcare Innovation with Ontologies"
]

ontology_summaries = [
    "Medical ontologies are structured representations of knowledge that facilitate the integration and exchange of information among health systems.",
    "Creating a medical ontology involves defining concepts, relationships, and rules that accurately and coherently reflect the health and medical domain.",
    "Ontologies enhance interoperability between electronic health systems, enabling easier access and analysis of clinical data.",
    "A well-designed ontology can support applications such as clinical decision-making, computer-assisted diagnosis, and biomedical research.",
    "The ontology creation process includes requirement gathering, concept modeling, validation, and ongoing maintenance.",
    "Tools like Protégé are widely used for developing and managing ontologies in the medical field.",
    "Standard medical ontologies, such as SNOMED CT and ICD, provide a common foundation for coding and exchanging clinical information.",
    "Shared semantics offered by ontologies facilitate the understanding and analysis of heterogeneous data from different sources.",
    "Integrating ontologies into Electronic Health Record (EHR) systems can improve the accuracy and efficiency of clinical documentation.",
    "Ontologies enable more effective semantic searches, enhancing the retrieval of relevant information in medical databases.",
    "Semantic interoperability is a key challenge that medical ontologies aim to address, ensuring that different systems understand and use data consistently.",
    "Collaboration between domain experts and developers is essential to create accurate and useful medical ontologies.",
    "Ontologies support the implementation of data standards in clinical research and epidemiological studies.",
    "The use of ontologies in medicine aids the development of artificial intelligence and machine learning by providing clear and well-defined knowledge structures.",
    "Medical ontologies can be adapted and expanded to include new discoveries and advancements in the health field.",
    "The quality and usability of a medical ontology depend on its ability to faithfully represent knowledge and relationships within the domain.",
    "Reusing existing ontologies can accelerate the development process and ensure consistency with recognized standards.",
    "Version management is important in creating medical ontologies to keep the knowledge representation up-to-date over time.",
    "Ontologies can be integrated with emerging technologies like the semantic web and open data services to drive innovation in healthcare.",
    "Impact analysis of medical ontologies allows evaluation of how they contribute to improving care quality and clinical process efficiency."
]

# Función para expandir el resumen a un rango entre 150 y 200 palabras
def expand_to_range(text, min_words=150, max_words=200):
    words = text.split()
    # Si el resumen es menor al mínimo, se repite el contenido
    if len(words) < min_words:
        original_words = words.copy()
        while len(words) < min_words:
            words.extend(original_words)
    # Si excede el máximo, se trunca a max_words palabras
    words = words[:max_words]
    return " ".join(words)

# Combinar los datos en una lista de diccionarios
rows = []

# Agregar resúmenes de Epilepsia
for title, summary in zip(epilepsy_titles, epilepsy_summaries):
    summary_expanded = expand_to_range(summary, 150, 200)
    rows.append({"titulo": title, "resumen": summary_expanded})

# Agregar resúmenes de Ontologías en Medicina
for title, summary in zip(ontology_titles, ontology_summaries):
    summary_expanded = expand_to_range(summary, 150, 200)
    rows.append({"titulo": title, "resumen": summary_expanded})

# Crear el archivo CSV con dos columnas: 'titulo' y 'resumen'
csv_filename = "summaries.csv"
with open(csv_filename, "w", newline="", encoding="utf-8") as csvfile:
    fieldnames = ["titulo", "resumen"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for row in rows:
        writer.writerow(row)

print(f"El archivo CSV '{csv_filename}' ha sido creado exitosamente con cada resumen entre 150 y 200 palabras.")
# Out:
# El archivo CSV 'summaries.csv' ha sido creado exitosamente con cada resumen entre 150 y 200 palabras.
