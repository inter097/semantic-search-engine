# %%
import os

# Directorio donde se guardarán los archivos
output_dir = "resumenes_textos"
os.makedirs(output_dir, exist_ok=True)

# Lista de resúmenes sobre Epilepsia (20 resúmenes)
epilepsia_resumenes = [
    "La epilepsia es un trastorno neurológico caracterizado por convulsiones recurrentes. Estas convulsiones son episodios temporales de actividad eléctrica anormal en el cerebro que pueden afectar el comportamiento, los movimientos, las sensaciones y la conciencia.",
    "El tratamiento de la epilepsia generalmente incluye medicamentos anticonvulsivos, pero en casos resistentes, se pueden considerar opciones como la cirugía, la estimulación del nervio vago o dietas especiales como la cetogénica.",
    "Las causas de la epilepsia son variadas e incluyen factores genéticos, lesiones cerebrales, infecciones, y condiciones como el accidente cerebrovascular. Sin embargo, en muchos casos, la causa exacta no se puede determinar.",
    "El diagnóstico de la epilepsia se realiza mediante la historia clínica del paciente, un examen neurológico y pruebas complementarias como el electroencefalograma (EEG) y la resonancia magnética (MRI).",
    "Vivir con epilepsia puede ser desafiante, pero con el tratamiento adecuado y el apoyo social, muchas personas con epilepsia llevan una vida plena y activa.",
    "Existen diferentes tipos de epilepsia, como la epilepsia focal y la generalizada, cada una con características clínicas y pronósticos distintos.",
    "Los factores desencadenantes de las convulsiones pueden incluir falta de sueño, estrés, luces intermitentes, y consumo de alcohol. Identificar y evitar estos desencadenantes es parte del manejo de la epilepsia.",
    "La epilepsia es una condición estigmatizada en muchas culturas, lo que puede llevar a la discriminación y el aislamiento social de quienes la padecen.",
    "Investigaciones recientes están explorando nuevos tratamientos para la epilepsia, incluyendo terapias génicas y nuevos fármacos anticonvulsivos con menos efectos secundarios.",
    "La epilepsia infantil es una subcategoría que aborda el diagnóstico y tratamiento de la epilepsia en niños, considerando el impacto en el desarrollo cognitivo y social.",
    "El soporte psicológico es fundamental para los pacientes con epilepsia, ayudándoles a manejar el estrés y la ansiedad asociados con la condición.",
    "La adherencia al tratamiento es crucial en la epilepsia para prevenir convulsiones, pero muchos pacientes enfrentan desafíos para mantener su régimen de medicamentos.",
    "La epilepsia refractaria es aquella que no responde a los tratamientos convencionales, requiriendo enfoques terapéuticos alternativos.",
    "Las crisis epilépticas pueden clasificarse en parciales simples, parciales complejas, y tónicas-clónicas generales, cada una con síntomas específicos.",
    "El impacto socioeconómico de la epilepsia es significativo, afectando la productividad laboral y generando costos en atención médica.",
    "La epilepsia y la depresión a menudo coexisten, lo que requiere un enfoque integral en el tratamiento para abordar ambas condiciones.",
    "La genética juega un papel en algunos tipos de epilepsia, y se están identificando genes específicos que aumentan el riesgo de desarrollar este trastorno.",
    "Las convulsiones nocturnas son comunes en la epilepsia y pueden afectar la calidad del sueño del paciente y sus familiares.",
    "La epilepsia puede influir en la conducción y otras actividades que requieren atención constante, por lo que se deben tomar precauciones para garantizar la seguridad del paciente.",
    "El estigma asociado con la epilepsia puede afectar la autoestima y las relaciones interpersonales de los individuos afectados."
]

# Lista de resúmenes sobre Creación de Ontologías en Medicina (20 resúmenes)
ontologias_resumenes = [
    "Las ontologías en medicina son representaciones estructuradas de conocimiento que facilitan la integración y el intercambio de información entre sistemas de salud.",
    "La creación de una ontología médica implica definir conceptos, relaciones y reglas que reflejan el dominio de la salud y la medicina de manera precisa y coherente.",
    "Las ontologías permiten mejorar la interoperabilidad entre sistemas electrónicos de salud, facilitando el acceso y análisis de datos clínicos.",
    "Una ontología bien diseñada puede soportar aplicaciones como la toma de decisiones clínicas, el diagnóstico asistido por computadora y la investigación biomédica.",
    "El proceso de creación de una ontología médica incluye la recolección de requisitos, la modelización de conceptos, la validación y el mantenimiento continuo.",
    "Herramientas como Protégé son ampliamente utilizadas para el desarrollo y gestión de ontologías en el ámbito médico.",
    "Las ontologías médicas estándar, como SNOMED CT y el ICD, proporcionan una base común para la codificación y el intercambio de información clínica.",
    "La semántica compartida que ofrecen las ontologías facilita la comprensión y el análisis de datos heterogéneos provenientes de diferentes fuentes.",
    "La integración de ontologías en sistemas de registro electrónico de salud (EHR) puede mejorar la precisión y la eficiencia en la documentación clínica.",
    "Las ontologías permiten la realización de búsquedas semánticas más efectivas, mejorando la recuperación de información relevante en bases de datos médicas.",
    "La interoperabilidad semántica es un desafío clave que las ontologías médicas buscan resolver, asegurando que los diferentes sistemas comprendan y utilicen los datos de manera consistente.",
    "La colaboración entre expertos en dominio y desarrolladores es esencial para crear ontologías médicas precisas y útiles.",
    "Las ontologías facilitan la implementación de estándares de datos en investigaciones clínicas y estudios epidemiológicos.",
    "El uso de ontologías en medicina apoya el desarrollo de inteligencia artificial y aprendizaje automático al proporcionar estructuras de conocimiento claras y bien definidas.",
    "Las ontologías médicas pueden adaptarse y expandirse para incluir nuevos descubrimientos y avances en el campo de la salud.",
    "La calidad y la usabilidad de una ontología médica dependen de su capacidad para representar fielmente el conocimiento y las relaciones dentro del dominio.",
    "La reutilización de ontologías existentes puede acelerar el proceso de desarrollo y asegurar la coherencia con estándares reconocidos.",
    "La gestión de versiones es importante en la creación de ontologías médicas para mantener actualizada la representación del conocimiento a lo largo del tiempo.",
    "Las ontologías pueden integrarse con tecnologías emergentes como la web semántica y los servicios de datos abiertos para potenciar la innovación en salud.",
    "El análisis de impacto de las ontologías en medicina permite evaluar cómo contribuyen a mejorar la calidad de la atención y la eficiencia de los procesos clínicos."
]

# Títulos para los archivos de Epilepsia
epilepsia_titulos = [
    "Introducción a la Epilepsia",
    "Tratamientos Actuales de la Epilepsia",
    "Causas de la Epilepsia",
    "Diagnóstico de la Epilepsia",
    "Vivir con Epilepsia",
    "Tipos de Epilepsia",
    "Factores Desencadenantes",
    "Estigma y Epilepsia",
    "Investigaciones Recientes",
    "Epilepsia Infantil",
    "Soporte Psicológico",
    "Adherencia al Tratamiento",
    "Epilepsia Refractaria",
    "Clasificación de Crisis",
    "Impacto Socioeconómico",
    "Epilepsia y Depresión",
    "Genética de la Epilepsia",
    "Convulsiones Nocturnas",
    "Seguridad y Epilepsia",
    "Efectos del Estigma"
]

# Títulos para los archivos de Ontologías en Medicina
ontologias_titulos = [
    "Fundamentos de las Ontologías Médicas",
    "Proceso de Creación de Ontologías",
    "Interoperabilidad en Sistemas de Salud",
    "Aplicaciones Clínicas de las Ontologías",
    "Herramientas para el Desarrollo de Ontologías",
    "Estándares de Ontologías Médicas",
    "Semántica Compartida en Salud",
    "Integración con Sistemas EHR",
    "Búsquedas Semánticas en Medicina",
    "Interoperabilidad Semántica",
    "Colaboración en el Desarrollo de Ontologías",
    "Ontologías en Investigación Clínica",
    "Apoyo a la Inteligencia Artificial",
    "Actualización y Mantenimiento de Ontologías",
    "Reutilización de Ontologías Existentes",
    "Gestión de Versiones en Ontologías",
    "Ontologías y Web Semántica",
    "Impacto de las Ontologías en Salud",
    "Evaluación de la Calidad de las Ontologías",
    "Innovación en Salud con Ontologías"
]

# Función para crear archivos
def crear_archivos(prefix, titulos, resumenes, inicio_num):
    for i, (titulo, resumen) in enumerate(zip(titulos, resumenes), start=inicio_num):
        filename = f"d{i}_{titulo.replace(' ', '_')}.txt"
        filepath = os.path.join(output_dir, filename)
        with open(filepath, "w", encoding="utf-8") as file:
            file.write(f"Resumen: {resumen}\n")
        print(f"Archivo creado: {filepath}")

# Crear 20 archivos de Epilepsia
crear_archivos("d", epilepsia_titulos, epilepsia_resumenes, 1)

# Crear 20 archivos de Ontologías en Medicina
crear_archivos("d", ontologias_titulos, ontologias_resumenes, 21)

print("\nTodos los archivos han sido creados exitosamente en la carpeta 'resumenes_textos'.")
# Out:
# Archivo creado: resumenes_textos\d1_Introducción_a_la_Epilepsia.txt
# Archivo creado: resumenes_textos\d2_Tratamientos_Actuales_de_la_Epilepsia.txt
# Archivo creado: resumenes_textos\d3_Causas_de_la_Epilepsia.txt
# Archivo creado: resumenes_textos\d4_Diagnóstico_de_la_Epilepsia.txt
# Archivo creado: resumenes_textos\d5_Vivir_con_Epilepsia.txt
# Archivo creado: resumenes_textos\d6_Tipos_de_Epilepsia.txt
# Archivo creado: resumenes_textos\d7_Factores_Desencadenantes.txt
# Archivo creado: resumenes_textos\d8_Estigma_y_Epilepsia.txt
# Archivo creado: resumenes_textos\d9_Investigaciones_Recientes.txt
# Archivo creado: resumenes_textos\d10_Epilepsia_Infantil.txt
# Archivo creado: resumenes_textos\d11_Soporte_Psicológico.txt
# Archivo creado: resumenes_textos\d12_Adherencia_al_Tratamiento.txt
# Archivo creado: resumenes_textos\d13_Epilepsia_Refractaria.txt
# Archivo creado: resumenes_textos\d14_Clasificación_de_Crisis.txt
# Archivo creado: resumenes_textos\d15_Impacto_Socioeconómico.txt
# ...
